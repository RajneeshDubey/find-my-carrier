# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
# from catboost import CatBoostClassifier
from connector import *
import warnings
warnings.filterwarnings(action='ignore')

# %%
#data = pd.read_csv('./data_dump_4k_exp3.csv')
data = pd.read_csv('./data_dump_40k_exp4.csv')
data
# Out:
#        from_address  to_addresss  weight     distance  delivery_req  \
# 0             28603        28603   46.37     0.000000             3
# 1             28603        59244   39.39  2492.876617             1
# 2             28603        83120   29.76  2668.212157             1
# 3             28603        83712   74.06  3088.264759             1
# 4             28603        46524   88.08   748.153429             1
# ...             ...          ...     ...          ...           ...
# 39995         52501        66629   76.46   354.932307             1
# 39996         52501        98547   54.83  2598.647838             2
# 39997         52501        27698   62.34  1332.435739             2
# 39998         52501        36512   52.65  1181.523405             3
# 39999         52501        52501   41.87     0.000000             1
#
#                                           shipping_costs  \
# 0      [46.37, 46.37, 67.37, 46.37, 63.37, 46.37, 67.37]
# ...

# %%
data['rating_0'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[0],
    axis=1
)
data['rating_1'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[1],
    axis=1
)
data['rating_2'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[2],
    axis=1
)
data['rating_3'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[3],
    axis=1
)
data['rating_4'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[4],
    axis=1
)
data['rating_5'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[5],
    axis=1
)
data['rating_6'] = data.apply(
    lambda row: row['ratings'].replace('[', '').replace(']', '').replace(' ','').split(',')[6],
    axis=1
)

# %%
data['otd_0'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[0],
    axis=1
)
data['otd_1'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[1],
    axis=1
)
data['otd_2'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[2],
    axis=1
)
data['otd_3'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[3],
    axis=1
)
data['otd_4'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[4],
    axis=1
)
data['otd_5'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[5],
    axis=1
)
data['otd_6'] = data.apply(
    lambda row: row['otds'].replace('[', '').replace(']', '').replace(' ','').split(',')[6],
    axis=1
)

# %%
data['shipping_cost_0'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[0],
    axis=1
)
data['shipping_cost_1'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[1],
    axis=1
)
data['shipping_cost_2'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[2],
    axis=1
)
data['shipping_cost_3'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[3],
    axis=1
)
data['shipping_cost_4'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[4],
    axis=1
)
data['shipping_cost_5'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[5],
    axis=1
)
data['shipping_cost_6'] = data.apply(
    lambda row: row['shipping_costs'].replace('[', '').replace(']', '').replace(' ','').split(',')[6],
    axis=1
)

# %%
data.dtypes
# Out:
# from_address             int64
# to_addresss              int64
# weight                 float64
# distance               float64
# delivery_req             int64
# shipping_costs          object
# ratings                 object
# otds                    object
# best_shipping_cost     float64
# carrier_ServiceType     object
# rating_0                object
# rating_1                object
# rating_2                object
# rating_3                object
# rating_4                object
# rating_5                object
# rating_6                object
# otd_0                   object
# otd_1                   object
# otd_2                   object
# otd_3                   object
# otd_4                   object
# otd_5                   object
# otd_6                   object
# shipping_cost_0         object
# shipping_cost_1         object
# shipping_cost_2         object
# shipping_cost_3         object
# shipping_cost_4         object
# shipping_cost_5         object
# ...

# %%
input_features = data.drop(columns=['shipping_costs', 'ratings', 'otds', 'best_shipping_cost']).reset_index()
input_features
# Out:
#        index  from_address  to_addresss  weight     distance  delivery_req  \
# 0          0         28603        28603   46.37     0.000000             3
# 1          1         28603        59244   39.39  2492.876617             1
# 2          2         28603        83120   29.76  2668.212157             1
# 3          3         28603        83712   74.06  3088.264759             1
# 4          4         28603        46524   88.08   748.153429             1
# ...      ...           ...          ...     ...          ...           ...
# 39995  39995         52501        66629   76.46   354.932307             1
# 39996  39996         52501        98547   54.83  2598.647838             2
# 39997  39997         52501        27698   62.34  1332.435739             2
# 39998  39998         52501        36512   52.65  1181.523405             3
# 39999  39999         52501        52501   41.87     0.000000             1
#
# ...

# %%
# Split df into X and y
y = input_features['carrier_ServiceType']
X = input_features.drop(columns=['carrier_ServiceType', 'index', 'from_address', 'to_addresss'], axis=1)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)

# Scale X
scaler = StandardScaler()
scaler.fit(X_train)
X_train.to_csv('X_train_data.csv', encoding='utf-8', index=False)
X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)

# %%
X_train
# Out:
#          weight  distance  delivery_req  rating_0  rating_1  rating_2  \
# 8224   0.376253 -0.230726      0.000439 -0.704249  0.703681       0.0
# 11219  0.305549 -0.399567      0.000439 -0.704249  0.703681       0.0
# 17353 -1.350793 -0.374414     -1.227953  1.419953  0.703681       0.0
# 15305  0.480576 -0.668971      0.000439 -0.704249  0.703681       0.0
# 30147 -0.787588 -0.818824     -1.227953  1.419953  0.703681       0.0
# ...         ...       ...           ...       ...       ...       ...
# 7813   1.336994  0.191146      1.228830 -0.704249 -1.421098       0.0
# 32511 -1.565678 -0.897462     -1.227953  1.419953  0.703681       0.0
# 5192   1.384130 -0.713602      0.000439 -0.704249  0.703681       0.0
# 12172  0.191869  0.079887     -1.227953  1.419953  0.703681       0.0
# 33003  1.704377  1.202939     -1.227953  1.419953  0.703681       0.0
#
#        rating_3  rating_4  rating_5  rating_6  ...         otd_4     otd_5  \
# ...

# %%
X_test
# Out:
#          weight  distance  delivery_req  rating_0  rating_1  rating_2  \
# 3841  -1.682131 -0.308702      1.228830 -0.704249 -1.421098       0.0
# 12898  1.434732 -0.256499      1.228830 -0.704249 -1.421098       0.0
# 15032  0.800130  0.414779      1.228830 -0.704249 -1.421098       0.0
# 36781 -0.652072  1.300192      1.228830 -0.704249 -1.421098       0.0
# 9201   0.459088  0.484987      1.228830 -0.704249 -1.421098       0.0
# ...         ...       ...           ...       ...       ...       ...
# 26173  0.433787 -0.529099     -1.227953  1.419953  0.703681       0.0
# 6764   0.005058 -0.085776     -1.227953  1.419953  0.703681       0.0
# 17508 -0.053862 -0.311943      1.228830 -0.704249 -1.421098       0.0
# 39650  0.997685 -0.583313      0.000439 -0.704249  0.703681       0.0
# 17293  0.982088 -0.145614      0.000439 -0.704249  0.703681       0.0
#
#        rating_3  rating_4  rating_5  rating_6  ...         otd_4     otd_5  \
# ...

# %%
models = {
    "                   Logistic Regression": LogisticRegression(),
    "                   K-Nearest Neighbors": KNeighborsClassifier(),
    "                         Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine (Linear Kernel)": LinearSVC(),
    "   Support Vector Machine (RBF Kernel)": SVC(),
    "                        Neural Network": MLPClassifier(),
    "                         Random Forest": RandomForestClassifier(),
#     "                     Gradient Boosting": GradientBoostingClassifier(),
}

for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + " trained.")
# Out:
#                    Logistic Regression trained.
#                    K-Nearest Neighbors trained.
#                          Decision Tree trained.
# Support Vector Machine (Linear Kernel) trained.
#    Support Vector Machine (RBF Kernel) trained.
#                         Neural Network trained.
#                          Random Forest trained.

# %%
for name, model in models.items():
    print(name + ": {:.2f}%".format(model.score(X_test, y_test) * 100))
# Out:
#                    Logistic Regression: 54.37%
#                    K-Nearest Neighbors: 47.95%
#                          Decision Tree: 43.98%
# Support Vector Machine (Linear Kernel): 54.37%
#    Support Vector Machine (RBF Kernel): 54.37%
#                         Neural Network: 53.77%
#                          Random Forest: 46.69%

# %%
filename = 'finalized_model.sav'
import pickle

# %%
pickle.dump(models["                   Logistic Regression"], open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model.predict(X_train)
# Out:
# array(['FEDEX_FEDEX_GROUND', 'FEDEX_FEDEX_GROUND', 'FEDEX_OVERNIGHT', ...,
#        'FEDEX_FEDEX_GROUND', 'FEDEX_OVERNIGHT', 'FEDEX_OVERNIGHT'],
#       dtype=object)

# %%
X_train
# Out:
#          weight  distance  delivery_req  rating_0  rating_1  rating_2  \
# 8224   0.376253 -0.230726      0.000439 -0.704249  0.703681       0.0
# 11219  0.305549 -0.399567      0.000439 -0.704249  0.703681       0.0
# 17353 -1.350793 -0.374414     -1.227953  1.419953  0.703681       0.0
# 15305  0.480576 -0.668971      0.000439 -0.704249  0.703681       0.0
# 30147 -0.787588 -0.818824     -1.227953  1.419953  0.703681       0.0
# ...         ...       ...           ...       ...       ...       ...
# 7813   1.336994  0.191146      1.228830 -0.704249 -1.421098       0.0
# 32511 -1.565678 -0.897462     -1.227953  1.419953  0.703681       0.0
# 5192   1.384130 -0.713602      0.000439 -0.704249  0.703681       0.0
# 12172  0.191869  0.079887     -1.227953  1.419953  0.703681       0.0
# 33003  1.704377  1.202939     -1.227953  1.419953  0.703681       0.0
#
#        rating_3  rating_4  rating_5  rating_6  ...         otd_4     otd_5  \
# ...

# %%
output=connectToModel('39442','99678',12,1)
output
list(X_train.columns)
# Out:
# ['weight',
#  'distance',
#  'delivery_req',
#  'rating_0',
#  'rating_1',
#  'rating_2',
#  'rating_3',
#  'rating_4',
#  'rating_5',
#  'rating_6',
#  'otd_0',
#  'otd_1',
#  'otd_2',
#  'otd_3',
#  'otd_4',
#  'otd_5',
#  'otd_6',
#  'shipping_cost_0',
#  'shipping_cost_1',
#  'shipping_cost_2',
#  'shipping_cost_3',
#  'shipping_cost_4',
#  'shipping_cost_5',
#  'shipping_cost_6']

# %%
output
# Out:
# {'from_address': '39442',
#  'to_addresss': '99678',
#  'distance': 5983.196567487434,
#  'weight': 12,
#  'delivery_req': 1,
#  'shipping_cost_0': 116.8879771165829,
#  'rating_0': 10,
#  'otd_0': 0.99,
#  'shipping_cost_1': 87.8879771165829,
#  'rating_1': 10,
#  'otd_1': 0.99,
#  'shipping_cost_2': 72.8879771165829,
#  'rating_2': 10,
#  'otd_2': 0.97,
#  'shipping_cost_3': 111.8879771165829,
#  'rating_3': 7,
#  'otd_3': 0.9,
#  'shipping_cost_4': 68.8879771165829,
#  'rating_4': 6,
#  'otd_4': 0.9,
#  'shipping_cost_5': 84.8879771165829,
#  'rating_5': 8,
#  'otd_5': 0.96,
#  'shipping_cost_6': 72.8879771165829,
#  'rating_6': 9,
#  'otd_6': 0.97}

# %%
data=[]
row2=[output['weight'],output['distance'],output['delivery_req'],output['rating_0'],output['rating_1'],output['rating_2'],output['rating_3'],output['rating_4'],output['rating_5'],output['rating_6'],output['otd_0'],output['otd_1'],output['otd_2'],output['otd_3'],output['otd_4'],output['otd_5'],output['otd_6'],output['shipping_cost_0'],output['shipping_cost_1'],output['shipping_cost_2'],output['shipping_cost_3'],output['shipping_cost_4'],output['shipping_cost_5'],output['shipping_cost_6']]
#rowdata=[8224,0.230726,-0.230726,0.000439,-0.704249,0.703681,0.0,-0.704249,0.0,0.703681,0.0,0.703681,0.703681,0.703681,0.703681,0.703681,0.703681,-0.304638,0.575478,0.268051,-0.276816,0.268051,0.557435,0.268051]
data.append(row2)
outdf= pd.DataFrame (data, columns = ['weight',
 'distance',
 'delivery_req',
 'rating_0',
 'rating_1',
 'rating_2',
 'rating_3',
 'rating_4',
 'rating_5',
 'rating_6',
 'otd_0',
 'otd_1',
 'otd_2',
 'otd_3',
 'otd_4',
 'otd_5',
 'otd_6',
 'shipping_cost_0',
 'shipping_cost_1',
 'shipping_cost_2',
 'shipping_cost_3',
 'shipping_cost_4',
 'shipping_cost_5',
 'shipping_cost_6'])
outdf=pd.DataFrame(scaler.transform(outdf), index=outdf.index, columns=outdf.columns)

# %%
list(outdf.columns)
# Out:
# ['weight',
#  'distance',
#  'delivery_req',
#  'rating_0',
#  'rating_1',
#  'rating_2',
#  'rating_3',
#  'rating_4',
#  'rating_5',
#  'rating_6',
#  'otd_0',
#  'otd_1',
#  'otd_2',
#  'otd_3',
#  'otd_4',
#  'otd_5',
#  'otd_6',
#  'shipping_cost_0',
#  'shipping_cost_1',
#  'shipping_cost_2',
#  'shipping_cost_3',
#  'shipping_cost_4',
#  'shipping_cost_5',
#  'shipping_cost_6']

# %%
loaded_model.predict(outdf)
# Out:
# array(['FEDEX_OVERNIGHT'], dtype=object)
